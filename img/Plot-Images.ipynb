# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %%
Building10 = mpimg.imread('Building17.png')
Building18 = mpimg.imread('Building18.png')
Building20 = mpimg.imread('Building20.png')
Building10Paint1 = mpimg.imread('Building17-paint1.png')
Building10Paint2 = mpimg.imread('Building18-paint1.png')
Building10OutputPaint1 = mpimg.imread('Building17-output-paint1.png')
Building10OutputPaint2 = mpimg.imread('Building18-output-paint1.png')

Building10OutputContext = mpimg.imread('Building18-output-tf-paint1.png')
Building10OutputContext2 = mpimg.imread('Building17-output-tf-paint1.png')
image1 = mpimg.imread('Building14-paint10.png')
image2 = mpimg.imread('Building14-paint10.png')
image3 = mpimg.imread('Building20-paint1.png')
image4 = mpimg.imread('Building20-output-paint1.png')
image5 = mpimg.imread('Building20-output-tf-paint1.png')
image6 = mpimg.imread('Building14.png')
image7 = mpimg.imread('Building10.jpg')
image8 = mpimg.imread('Building10-paint2.jpg')
image9 = mpimg.imread('Building10-output-paint2.png')
image10 = mpimg.imread('Building10-nt-output-paint2.png')
image11 = mpimg.imread('Building14-paint11.png')
image12 = mpimg.imread('Building14-output-paint11.png')
image13 = mpimg.imread('Building14-output-tf-paint11.png')

# %%
print(Building10.shape)
print(Building10OutputContext.shape)
# Out:
# (195, 199, 4)
# (196, 198, 4)

# %%
fig, ax = plt.subplots(5,4, figsize=(15,18))
fig.subplots_adjust(hspace= -0.5, wspace=0.1)

ax[0,0].axis('off')  
ax[0,0].set_title('Training Image')
ax[0,0].imshow(Building10)
ax[1,0].axis('off') 
ax[1,0].imshow(Building18)
ax[2,0].axis('off') 
ax[2,0].imshow(Building20)
ax[3,0].axis('off') 
ax[3,0].imshow(image6)
ax[4,0].axis('off') 
ax[4,0].imshow(image7)


ax[0,1].imshow(Building10Paint1)
ax[0,1].set_title('Input')
ax[0,1].axis('off') 
ax[1,1].imshow(Building10Paint2)
ax[1,1].axis('off')
ax[1,1].imshow(Building10Paint2)
ax[1,1].axis('off') 
ax[2,1].imshow(image3)
ax[2,1].axis('off')
ax[3,1].imshow(image11)
ax[3,1].axis('off')
ax[4,1].imshow(image8)
ax[4,1].axis('off')



ax[0,2].imshow(Building10OutputPaint1)
ax[0,2].set_title('SinGAN')
ax[0,2].axis('off') 
ax[1,2].imshow(Building10OutputPaint2)
ax[1,2].axis('off')
ax[2,2].imshow(image4)
ax[2,2].axis('off')
ax[3,2].imshow(image12)
ax[3,2].axis('off')
ax[4,2].imshow(image9)
ax[4,2].axis('off')


ax[0,3].set_title('Neural Style Transfer')
ax[0,3].imshow(Building10OutputContext2)
ax[0,3].axis('off')
ax[1,3].imshow(Building10OutputContext)
ax[1,3].axis('off')
ax[2,3].imshow(image5)
ax[2,3].axis('off')
ax[3,3].imshow(image13)
ax[3,3].axis('off')
ax[4,3].imshow(image10)
ax[4,3].axis('off')




plt.savefig("figure-Building10")
